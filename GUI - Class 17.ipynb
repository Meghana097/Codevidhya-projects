# %%
from tkinter import *

window=Tk()
window.title("Calculator")
window.geometry("800x800")

equation = StringVar()
equation1 = Entry(window, textvariable=equation)
equation1.grid(columnspan=6, row=0)
expression = ""
def function_1(num):
    global expression
    expression = expression + str(num)
    equation.set(expression)
def function_2():
    try:
        global expression 
        total=str(eval(expression))
        equation.set(total)
        expression = ""
    except:
        equation.set("Error")
        expression=""
def clear_function():
    global expresion 
    expression=""
    equation.set("")


        
    
    

v1=Button(window, text="A/C", command=clear_function, width=4, height=2, fg='blue')
v1.grid(row=1, column=0)

v2=Button(window, text="+", command=lambda:function_1("+"), width=4, height=2, fg='blue')

v2.grid(row=1, column=1)

v21=Button(window, text="-", command=lambda:function_1("-"), width=4, height=2)

v21.grid(row=5, column=2)

v22=Button(window, text="/", command=lambda:function_1("/"), width=4, height=2, fg='blue')

v22.grid(row=1, column=3)

v23=Button(window, text="*", command=lambda:function_1("*"), width=4, height=2)

v23.grid(row=2, column=3)

v24=Button(window, text=".", command=lambda:function_1("."), width=4, height=2)

v24.grid(row=3, column=3)

v3=Button(window, text="%", width=4, height=2, bg='blue')

v3.grid(row=1, column=2)

v4=Button(window, text="/", command=lambda:function_1("/"), width=4, height=2)

v4.grid(row=1, column=3)

v7=Button(window, text="1", command=lambda:function_1("1"), width=4, height=2)

v7.grid(row=2, column=0)

v8=Button(window, text="2", command=lambda:function_1("2"), width=4, height=2)

v8.grid(row=3, column=0)

v9=Button(window, text="3", command=lambda:function_1("3"), width=4, height=2)

v9.grid(row=4, column=0)

v10=Button(window, text="4", command=lambda:function_1("4"), width=4, height=2)

v10.grid(row=5, column=0)

v11=Button(window, text="5", command=lambda:function_1("5"),width=4, height=2)

v11.grid(row=2, column=1)

v11=Button(window, text="6", command=lambda:function_1("6"), width=4, height=2)

v11.grid(row=3, column=1)

v12=Button(window, text="7", command=lambda:function_1("7"), width=4, height=2)

v12.grid(row=4, column=1)

v13=Button(window, text="8", command=lambda:function_1("8"), width=4, height=2)

v13.grid(row=5, column=1)

v14=Button(window, text="9", command=lambda:function_1("9"), width=4, height=2)

v14.grid(row=2, column=2)

v15=Button(window, text="0", command=lambda:function_1("0"), width=4, height=2)

v15.grid(row=3, column=2)

button1=Button(window, text="=", command=function_2, width=4, height=2)

button1.grid(row=4, column=2)

mainloop()
